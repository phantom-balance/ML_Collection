# %% [markdown]
# <a href="https://colab.research.google.com/github/phantom-balance/ML_collection/blob/master/image_to_captions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cloning and downloading necessary materials

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/phantom-balance/ML_collection.git
# Out:
# Cloning into 'ML_collection'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 1), reused 19 (delta 0), pack-reused 0
# Unpacking objects: 100% (20/20), done.

# %%
# %cd ML_collection/IMG_CAP
# %ls
# Out:
# /content/ML_collection/IMG_CAP
# Image/      loader.py  __pycache__/  train.py
# img_cap.py  model.py   test.py       utils.py

# %%
# !curl -s https://raw.githubusercontent.com/sivel/speedtest-cli/master/speedtest.py | python -
# !curl -s http://checkip.amazonaws.com

# %%
# !cp -av '/content/drive/MyDrive/DATA/flickr8k' '/content/ML_collection/IMG_CAP'

# %% [markdown]
# #TRAINING

# %%
# !python train.py

# %%
from google.colab import files
files.download('/content/ML_collection/IMG_CAP/IMG_CAP.pth.tar')

# %% [markdown]
# #TESTING

# %%
from IPython.display import Image

# %%
# Downloading Model parameters(Already trained)
# !gdown --id 15OiJTC3pE2qugzL5yCdqLMoxkUG9Ju0d
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=15OiJTC3pE2qugzL5yCdqLMoxkUG9Ju0d
# To: /content/ML_collection/IMG_CAP/IMG_CAP.pth.tar
# 100% 119M/119M [00:01<00:00, 80.5MB/s]

# %%
from img_cap import img_cap
img_id_list = ["doggo.jpg","Important.png"]
img_cap(root_dir="Image", img_id_list=img_id_list)
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
#   0%|          | 0.00/104M [00:00<?, ?B/s]
# __Loading checkpoint__
# doggo.jpg:a brown dog is running through the grass .
# Important.png:a man in a black shirt and a black hat is standing in front of a brick wall .

# %%
img_id_list = ["doggo.jpg"]
img_cap(root_dir="Image", img_id_list=img_id_list)
Image('Image/doggo.jpg')
# Out:
# __Loading checkpoint__
# doggo.jpg:a brown dog is running through the grass .

# %%
img_id_list = ["Important.png"]
img_cap(root_dir="Image", img_id_list=img_id_list)
Image('Image/Important.png')
# Out:
# __Loading checkpoint__
# Important.png:a man in a black shirt and a black hat is standing in front of a brick wall .
