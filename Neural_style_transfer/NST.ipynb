# %% [markdown]
# <a href="https://colab.research.google.com/github/phantom-balance/ML_collection/blob/master/Neural_style_transfer/NST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/phantom-balance/ML_collection.git
# Out:
# Cloning into 'ML_collection'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 43 (delta 8), reused 32 (delta 3), pack-reused 0
# Unpacking objects: 100% (43/43), done.

# %%
# %cd ML_collection/Neural_style_transfer
# %ls
# Out:
# /content/ML_collection/Neural_style_transfer
# Image/  VGG19_NST.py

# %%
from IPython.display import Image

# %%
# Content Image
Image('Image/Content.jpg')

# %%
# Style Image
Image('Image/Style.jpg')

# %%
from VGG19_NST import img_create
img_create(original_img="Image/Content.jpg", style_img="Image/Style.jpg", alpha=0.5, beta=1)

# %%
# Van Gough's Doggo
Image('Image/generated4150.png')
